# %% [markdown]
# <a href="https://colab.research.google.com/github/davro76/AVANSETools/blob/master/PracticalDataMiningWithTwitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy
# !pip install tweepy --upgrade
# !pip install better_profanity
import tweepy
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAADRyiwEAAAAAVyAignb%2BpcKAU5rCs%2BAI5Q45Vyk%3DIC8kWmSHu9dkNW8j2PGBs2DpSkMiKmBFkoE7S6WcaprBHhIfil')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Collecting tweepy
#   Downloading tweepy-4.12.0-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 3.1 MB/s
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (3.2.2)
# Collecting requests<3,>=2.27.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy) (2.1.1)
# Installing collected packages: requests, tweepy
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 3.10.0
#     Uninstalling tweepy-3.10.0:
#       Successfully uninstalled tweepy-3.10.0
# Successfully installed requests-2.28.1 tweepy-4.12.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting better_profanity
#   Downloading better_profanity-0.7.0-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.0 MB/s
# Installing collected packages: better-profanity
# Successfully installed better-profanity-0.7.0

# %%
import tweepy

your_query = "Miami Dade College"
query = your_query + ' -is:retweet'

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)

for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# I’m not just saying this. I am actually registered to take a class in Miami Dade College Wolfson Campus in Downtown Miami in the evening and their Kickstart program paid for it and books will be paid for next year starting January 2023.
# [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855447833045946370', 'name': 'Miami', 'description': 'Miami'}}]
# I have been working with Catalyst Miami on getting trying to get myself better opportunities. I could get a job with Miami Dade Public Schools with my associates degree from college. The problem is that I need recommendation letters and don’t know many people now.
# [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855447833045946370', 'name': 'Miami', 'description': 'Miami'}}]
# @CharlieCrist @valdemings While campaigning for CharlieCrist in Miami-Dade County, JoeBiden claims that he went to college at a HBCU (Historically Black institution) Delaware State University.
#
# He didn't... He went to the University of Delaware.Biden is a pathological liar, BS politician.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '966044405365841920', 'name': 'Val Demings', 'description': 'US Representative Val Demings (FL-10)'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '966044680789008384', 'name': 'Charlie Crist', 'description': 'US Representative Charlie Crist (FL-13)'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1573012192638574592', 'name': "Florida's U.S. Senate election, 2022"}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1573015096879562752', 'name': "Florida's gubernatorial election, 2022"}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '966044405365841920', 'name': 'Val Demings', 'description': 'US Representative Val Demings (FL-10)'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '966044680789008384', 'name': 'Charlie Crist', 'description': 'US Representative Charlie Crist (FL-13)'}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1573012192638574592', 'name': "Florida's U.S. Senate election, 2022"}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1573015096879562752', 'name': "Florida's gubernatorial election, 2022"}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '966044405365841920', 'name': 'Val Demings', 'description': 'US Representative Val Demings (FL-10)'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '966044680789008384', 'name': 'Charlie Crist', 'description': 'US Representative Charlie Crist (FL-13)'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1291447199595782144', 'name': 'United States politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1488973753274929152', 'name': 'Political events'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1518940645343125504', 'name': 'United States politic ...
# I'm at Miami Dade College Kendall Campus - @mdcollege in Miami, FL https://t.co/b6uGm0uuwn
# [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855447833045946370', 'name': 'Miami', 'description': 'Miami'}}]
# I checked in at Miami Dade College Kendall Campus on #Yelp https://t.co/Yguxvnk9i3
# [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855447833045946370', 'name': 'Miami', 'description': 'Miami'}}]
# Miami Dade College among local women’s basketball programs with potential this season  https://t.co/RC0wrLBLxz
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1254792035480952833', 'name': 'South Florida'}}, {'domain': {'id': '171', 'name': 'Local News', 'description': 'For local-level news entities'}, 'entity': {'id': '1254792035480952833', 'name': 'South Florida'}}, {'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '706083902411055104', 'name': 'Basketball'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '706083902411055104', 'name': 'Basketball'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855447833045946370', 'name': 'Miami', 'description': 'Miami'}}]
# Miami Dade College among local women’s basketball programs with potential this season  https://t.co/eigkZXouaN
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '706083902411055104', 'name': 'Basketball'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '706083902411055104', 'name': 'Basketball'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855447833045946370', 'name': 'Miami', 'description': 'Miami'}}]
# Miami Dade College among local women’s basketball programs with potential this season https://t.co/ZbqnYfLeUu
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '706083902411055104', 'name': 'Basketball'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '706083902411055104', 'name': 'Basketball'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855447833045946370', 'name': 'Miami', 'description': 'Miami'}}]
# While campaigning for @CharlieCrist in Miami-Dade County, @JoeBiden claims that he went to college at a HBCU (Historically Black institution) Delaware State University.
#
# He didn't... He went to the University of Delaware. https://t.co/QtdeQPHDny
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '966044680789008384', 'name': 'Charlie Crist', 'description': 'US Representative Charlie Crist (FL-13)'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1573015096879562752', 'name': "Florida's gubernatorial election, 2022"}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '966044680789008384', 'name': 'Charlie Crist', 'description': 'US Representative Charlie Crist (FL-13)'}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1573015096879562752', 'name': "Florida's gubernatorial election, 2022"}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '966044680789008384', 'name': 'Charlie Crist', 'description': 'US Representative Charlie Crist (FL-13)'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1291447199595782144', 'name': 'United States politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1488973753274929152', 'name': 'Political events'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1518940645343125504', 'name': 'United States political events'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1573015096879562752', 'name': "Florida's gubernatorial election, 2022"}}, {'domain': {'id': '159', 'name': 'States', 'description': 'States, provinces, or prefectures, like California or Fukushima Prefecture'}, 'entity': {'id': '1004435667005333504', 'name': 'Delaware', 'description': 'Delaware'}}, {'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855447833045946370', 'name': 'Miami', 'description': 'Miami'}}]
# https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png
# https://pbs.twimg.com/profile_images/1345139662365417473/vhBKb-Rn_normal.jpg
# https://pbs.twimg.com/profile_images/771111833759522816/YSd3jxiM_normal.jpg
# https://pbs.twimg.com/profile_images/1587799362083725313/uPC0wWBq_normal.jpg
# https://pbs.twimg.com/profile_images/1536181105937850370/_gjUWxAA_normal.jpg
# https://pbs.twimg.com/profile_images/1517373233841852416/CwaEL6jk_normal.jpg
# https://pbs.twimg.com/profile_images/1556946035523686402/rJRsHz8z_normal.jpg
# https://pbs.twimg.com/profile_images/1483308433835130882/HclxgrPn_normal.jpg
# https://pbs.twimg.com/profile_images/1557295072458293248/BHjdasY6_normal.png
# https://pbs.twimg.com/profile_images/1581202834275504128/4xY9ZnJv_normal.jpg

# %% [markdown]
# # **Twitter Sentiment Analysis through Data Mining**

# %%
import re 

import numpy as np

import tweepy 

from tweepy import OAuthHandler 

from textblob import TextBlob 

import matplotlib.pyplot as plt

import pandas as pd

from wordcloud import WordCloud

from better_profanity import profanity

# %%
your_query = input("Please enter your topic / person of interest: ")
# your_query = "Ukraine"
query = your_query + ' -is:retweet'
# get tweets from the API
tweets = client.search_recent_tweets(query=query,
                                     tweet_fields = ["created_at", "text", "source"],
                                     user_fields = ["name", "username", "location", "verified", "description"],
                                     max_results = 100,
                                     expansions='author_id'
                                     )
# Out:
# Please enter your topic / person of interest: Elon Musk

# %%
# import the pandas library
import pandas as pd
# create a list of records
tweet_info_ls = []
# iterate over each tweet and corresponding user details
for tweet, user in zip(tweets.data, tweets.includes['users']):
    tweet_info = {
        'created_at': tweet.created_at,
        'text': tweet.text,
        'source': tweet.source,
        'name': user.name,
        'username': user.username,
        'location': user.location,
        'verified': user.verified,
        'description': user.description
    }
    tweet_info_ls.append(tweet_info)
# create dataframe from the extracted records
tweets_df = pd.DataFrame(tweet_info_ls)
# display the dataframe
tweets_df.head()
# Out:
#                  created_at  \
# 0 2022-11-03 00:32:13+00:00
# 1 2022-11-03 00:32:13+00:00
# 2 2022-11-03 00:32:11+00:00
# 3 2022-11-03 00:32:11+00:00
# 4 2022-11-03 00:32:11+00:00
#
#                                                 text              source  \
# 0  “Your Feedback Is Appreciated, Now Pay $8” – E...       WordPress.com
# 1  "Your Feedback Is Appreciated, Now Pay $8" - E...  Twitter for iPhone
# 2  people who stan billionaires are weird like wh...  Twitter for iPhone
# 3  Elon Musk to Cut Half of Twitter  https://t.co...  Twitter for iPhone
# 4           I can easily beat Elon musk in a fight 💯  Twitter for iPhone
#
#             name       username                    location  verified  \
# 0    _ReportWire    _ReportWire             Los Angeles, CA     False
# 1        jujuone      jujuone12                        None     False
# 2         monica  waystarroyhoe                Brooklyn, NY     False
# 3    Tom Hearden     followtheh                        None     False
# 4  choqui chis 👹      iced_piss  en la casa de tu mamá jaja     False
#
#                                          description
# 0  24/7 Headlines & Breaking News From Around the...
# 1
# 2  writer person. sponsored by pepto bismol. (she...
# 3  Hedge Fund trader and manager. Former sell sid...
# 4                  Dani ( ˘̀︹˘́ ) ☭ || She/Her || 20

# %%
# import the pandas library
import pandas as pd
# create a list of records
tweet_info_ls = []
# iterate over each tweet and corresponding user details
for tweet, user in zip(tweets.data, tweets.includes['users']):
    tweet_info = {
        'text': tweet.text,
        'username': user.username,
        'location': user.location,
    }
    tweet_info_ls.append(tweet_info)
# create dataframe from the extracted records
tweets_df = pd.DataFrame(tweet_info_ls)
# display the dataframe
tweets_df.head()
# Out:
#                                                 text       username  \
# 0  “Your Feedback Is Appreciated, Now Pay $8” – E...    _ReportWire
# 1  "Your Feedback Is Appreciated, Now Pay $8" - E...      jujuone12
# 2  people who stan billionaires are weird like wh...  waystarroyhoe
# 3  Elon Musk to Cut Half of Twitter  https://t.co...     followtheh
# 4           I can easily beat Elon musk in a fight 💯      iced_piss
#
#                      location
# 0             Los Angeles, CA
# 1                        None
# 2                Brooklyn, NY
# 3                        None
# 4  en la casa de tu mamá jaja

# %%
tweets_df.shape
# Out:
# (99, 3)

# %%
# Create a function to clean the tweets. Remove profanity, unnecessary characters, spaces, and stopwords.

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    r = tweet.lower()
    r = profanity.censor(r)
    r = re.sub("'", "", r) # This is to avoid removing contractions in english
    r = re.sub("@[A-Za-z0-9_]+","", r)
    r = re.sub("#[A-Za-z0-9_]+","", r)
    r = re.sub(r'http\S+', '', r)
    r = re.sub('[()!?]', ' ', r)
    r = re.sub('\[.*?\]',' ', r)
    r = re.sub("[^a-z0-9]"," ", r)
    r = r.split()
    stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
    r = [w for w in r if not w in stopwords]
    r = " ".join(word for word in r)
    return r

# %%
tweets_df.iloc[0,0]
# Out:
# '“Your Feedback Is Appreciated, Now Pay $8” – Elon Musk Calls Out Dopey AOC In A Pair of\xa0Tweets https://t.co/IdKnGwmxNl'

# %%
tweets_df["text"].iloc[0]
# Out:
# '“Your Feedback Is Appreciated, Now Pay $8” – Elon Musk Calls Out Dopey AOC In A Pair of\xa0Tweets https://t.co/IdKnGwmxNl'

# %%
tweet_list = tweets_df.text.to_list()

# %%
cleaned = [clean_tweet(tw) for tw in tweet_list]
cleaned
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   after removing the cwd from sys.path.
# ['your feedback is appreciated now pay 8 elon musk calls out aoc pair tweets',
#  'your feedback is appreciated now pay 8 elon musk calls out aoc pair tweets',
#  'people who stan billionaires are weird like why are you elon musk fan be fr',
#  'elon musk cut half twitter',
#  'i can easily beat elon musk fight',
#  'elon musk his transhumanist horseshit he dressed as satans servant halloween too',
#  'elon musk certooo que trabalharia na vought',
#  'elon musk petista por essa ningu m esperava',
#  'elon musk could enable twitter s edit button everyone as soon as next week',
#  'elon musk is asking 8 dollars month group comprised probably 99 9 multi millionaires if you aren t worth over million have opinion you d like share how that s wrong just stop',
#  'elon musks twitter is already over people',
#  'signed up elon musk meltdown stayed comedy meltdown',
#  'elon musk takes page out mark zuckerberg s social media playbook by',
#  'est s ideas que elon musk implementa son algunas que ya est n hechas en socios o subs en fb que ahora es meta 8 00 dlls es excelente pero no me gustar verificar me as es como comprar un t tulo de la universidad y me reconocieran algo que no soy o sea famoso',
#  'facebook twitter elon musk twitter twitter post',
#  'no thats definitely backsliding youre thinking about when someone regrets their actions tries undo them like when elon musk tried unbuy that one app',
#  'elon musk could enable twitter s edit button everyone',
#  'elon musk could enable twitter s edit button everyone',
#  'va s rement marier des mecs who aspire be like elon musk',
#  'one elon musk s gambits help twitter raise some cash is paywalled video feature that sure could be used all sorts things but let s be real here it d probably mostly be',
#  'elon musk gotta be goat troll',
#  'elon musk leaks terrifying twitter information via',
#  'elon musk only time ai turst model future not human turst',
#  'elon musk i wrote paper grad school him amp realized he is stain not someone admire i stick admiring my grandmother mother great grandmother they arent complete disappointments',
#  'elon musk is ignorant person who has enough blood money pretend be smart',
#  'california twitter workers who have stuck around are being ordered work 84 hour weeks 12 hours day seven days week meet elon musks tight deadlines',
#  'elon musk o novo s mbolo da extrema direita',
#  'elon musks new private jet is something behold but how bad is it climate',
#  'elon musk is lowkey great name pet lizard',
#  'mit den k uflichen blauen haken bef rdert elon musk fakenews wer kann dann noch z b olaf scholz von einem gefakten olaf scholz unterscheiden',
#  'elon musk could enable twitter s edit button everyone',
#  'elon musk is african mud',
#  'i will pay 8 month say i will worship aocs feet this elon musk bird app',
#  'musk few more weeks before twitter restores banned users',
#  'bloomberg reports that elon musk is set cut around 3 700 jobs at twitter x',
#  'twitter stop pushing your snake oil joe biden your who follow section as its not good look as which side you are be neutral free speech under elon musks ownership manual or does he have clean swamp further here too',
#  'elon musk keep funding key satellite links confirms ukrainian official bestyweb',
#  'kim kardashian tims place start with his family friends next place saturday night night my love you too much more than one most important thing is you',
#  'elon musk',
#  'can elon musk remove those promoted tweets comment section',
#  'se o elon musk fosse brasileiro verifica o no twitter 0 taxa de servi o 8',
#  'mas me disseram que com o elon musk',
#  'elon musk is set cut around 3 700 jobs at twitter',
#  'elon musk plans start twitter verification sale as soon as monday',
#  'elon musk 8 d lares las verificaciones elon musk 16 d lares las listas',
#  'elon musk also owns aoc',
#  'ltima hora elon musk eliminar el 50 de los empleos de twitter bloomberg',
#  '',
#  'elon musk ousts board named sole director',
#  'i aswear i dey feel elon musk pass',
#  'elon musk is expensive you need at least 800 5 mins time is money my dear',
#  'i honestly cant wait see elon musk crying over all those fake accounts with checkmarks doing some really offensive tweets whit his name',
#  'his name is elon musk hahahahahha',
#  'halts maul elon musk mir doch schei egal ob dir der laden geh rt',
#  'pues elon musk no es tesla ser una cara importante pero seguro hay mujeres que han tomado muchas decisiones en nombre no de musk sino en nombre de tesla as que no hay porque ag itarse',
#  'elon musk is controversial character currently but i made 19 his purchase twitter which will allow me be verified two months buy couple apple pies at mcdonalds',
#  'elon musk when i remind him that food is more important than internet member ship badge',
#  'everyone praising elon musk remember that he had jeffrey epsteins accomplice ghislaine maxwell at his wedding so image is real image with elon ghislaine cover time magazine was fake',
#  'wow elon you are so edgy cool not caring wow i love elon musk so much things he says wow i think i like him more than any other billionaire which i deify which is all them',
#  'elon musk is such somehow he just gets more more annoying he s blowhard like trump but without charisma',
#  'i would pay 8 per month twitter but i will never pay elon musk 8 per month twitter',
#  'this is how elon musk is doing it',
#  'elon musk could enable twitter s edit button everyone',
#  'elon musk changed like retweet button these these',
#  'it s elon musk dog he s being larping as intellectual longest now',
#  'when you find out elon musk owns child slaves congo',
#  '',
#  'se o elon musk estragar o twitter juro que crio o twitter dnv',
#  'una pena no pueda expresar adecuadamente el asco que da esta persona y estar feo por motivos evidentes pero le plantaba 27 kys como la copa de un pino y ojal se lo plantease etiquetando al elon musk y la jk pa que lo difundan y poniendo cosas como estas sin iron alguna',
#  'elon musk s latest twitter poll puts advertisers spot',
#  'i love it that elon musks inner monolgue is verified account',
#  'would you pay 8 month be verified twitter user heres what people platform verified unverified had say about ceo elon musk s idea',
#  'well when you begin pay 8 monthly attention space you will begin see value your time give it what is beneficial you i dont see much wrong with elon musks decision adopt scheme',
#  'why elon musk is so desperate twitter make money',
#  '',
#  'le twitter c st moi',
#  'sources elon musk plans cut 3 700 jobs at twitter half companys workforce starting november 4 reverse its existing work anywhere policy bloomberg',
#  'spoiler alert elon musk',
#  'bloomberg elon musk eliminate 50 all jobs save costs',
#  'thank you steve saying so eloquently what many millions us think about elon musk megalomaniac i just subscribed warning by steve schmidt',
#  'twitter laid me off today',
#  'elon musk don t give f',
#  'elons plans make twitter money ranked',
#  'la religion comunista se basa en el ego estas advertido elon musk',
#  'so tell me exactly what elon musk has contributed society',
#  'elon musk plans cut half twitter employees jobs bloomberg news reporter tweet',
#  'today update breaking elon musk eliminate 50 all twitter jobs save costs per bloomberg',
#  'elon musk kinda annoying',
#  '',
#  'e o pior que s o absurdas acabei de ouvir que o elon musk fez um sat lite pra hackear s urnas',
#  'elon musk type cream his jeans when someone says you sir just won internet',
#  'elon musk could enable twitter s edit button everyone',
#  'right wingers are already turning elon musk rolling stone',
#  'agora v o chamar o elon musk de comunista',
#  'elon musk plans charge 8 per month twitter verification status move that has left many users seeing red',
#  'now i can comment that trump won election thank you elon musk',
#  'its such science fiction name isnt it you can imagine early episode stargate sg1 where jack oneill antagonises some city elder called elon musk far off planet because daniel jacksons done something big hearted but unfortunate',
#  'are u as well rhesus negative just like elon musk',
#  'elon musk plans cut about 3 700 jobs at twitter or half social media company s workforce bid drive down cost twtr']

# %%
# Define the sentiment objects using TextBlob

sentiment_objects = [TextBlob(tweet) for tweet in cleaned]

sentiment_objects[0].polarity, sentiment_objects[0]
# Out:
# (0.2,
#  TextBlob("your feedback is appreciated now pay 8 elon musk calls out aoc pair tweets"))

# %%
# Create a list of polarity values and tweet text

sentiment_values = [[tweet.sentiment.polarity, str(tweet)] for tweet in sentiment_objects]

# Print the value of the 0th row.

sentiment_values[0]
# Print all the sentiment values

sentiment_values[0:99]
# Out:
# [[0.2,
#   'your feedback is appreciated now pay 8 elon musk calls out aoc pair tweets'],
#  [0.2,
#   'your feedback is appreciated now pay 8 elon musk calls out aoc pair tweets'],
#  [-0.5,
#   'people who stan billionaires are weird like why are you elon musk fan be fr'],
#  [-0.16666666666666666, 'elon musk cut half twitter'],
#  [0.43333333333333335, 'i can easily beat elon musk fight'],
#  [0.0,
#   'elon musk his transhumanist horseshit he dressed as satans servant halloween too'],
#  [0.0, 'elon musk certooo que trabalharia na vought'],
#  [0.0, 'elon musk petista por essa ningu m esperava'],
#  [0.0,
#   'elon musk could enable twitter s edit button everyone as soon as next week'],
#  [-0.1,
#   'elon musk is asking 8 dollars month group comprised probably 99 9 multi millionaires if you aren t worth over million have opinion you d like share how that s wrong just stop'],
#  [0.0, 'elon musks twitter is already over people'],
#  [0.0, 'signed up elon musk meltdown stayed comedy meltdown'],
#  [0.03333333333333333,
#   'elon musk takes page out mark zuckerberg s social media playbook by'],
#  [0.0,
#   'est s ideas que elon musk implementa son algunas que ya est n hechas en socios o subs en fb que ahora es meta 8 00 dlls es excelente pero no me gustar verificar me as es como comprar un t tulo de la universidad y me reconocieran algo que no soy o sea famoso'],
#  [0.0, 'facebook twitter elon musk twitter twitter post'],
#  [-0.06666666666666667,
#   'no thats definitely backsliding youre thinking about when someone regrets their actions tries undo them like when elon musk tried unbuy that one app'],
#  [0.0, 'elon musk could enable twitter s edit button everyone'],
#  [0.0, 'elon musk could enable twitter s edit button everyone'],
#  [0.0, 'va s rement marier des mecs who aspire be like elon musk'],
#  [0.39999999999999997,
#   'one elon musk s gambits help twitter raise some cash is paywalled video feature that sure could be used all sorts things but let s be real here it d probably mostly be'],
#  [0.0, 'elon musk gotta be goat troll'],
#  [-1.0, 'elon musk leaks terrifying twitter information via'],
#  [0.0, 'elon musk only time ai turst model future not human turst'],
#  [0.45,
#   'elon musk i wrote paper grad school him amp realized he is stain not someone admire i stick admiring my grandmother mother great grandmother they arent complete disappointments'],
#  [0.10714285714285714,
#   'elon musk is ignorant person who has enough blood money pretend be smart'],
#  [-0.17857142857142858,
#   'california twitter workers who have stuck around are being ordered work 84 hour weeks 12 hours day seven days week meet elon musks tight deadlines'],
#  [0.0, 'elon musk o novo s mbolo da extrema direita'],
#  [-0.18787878787878784,
#   'elon musks new private jet is something behold but how bad is it climate'],
#  [0.8, 'elon musk is lowkey great name pet lizard'],
#  [0.0,
#   'mit den k uflichen blauen haken bef rdert elon musk fakenews wer kann dann noch z b olaf scholz von einem gefakten olaf scholz unterscheiden'],
#  [0.0, 'elon musk could enable twitter s edit button everyone'],
#  [0.0, 'elon musk is african mud'],
#  [0.0,
#   'i will pay 8 month say i will worship aocs feet this elon musk bird app'],
#  [0.15, 'musk few more weeks before twitter restores banned users'],
#  [0.0,
#   'bloomberg reports that elon musk is set cut around 3 700 jobs at twitter x'],
#  [0.10416666666666669,
#   'twitter stop pushing your snake oil joe biden your who follow section as its not good look as which side you are be neutral free speech under elon musks ownership manual or does he have clean swamp further here too'],
#  [0.0,
#   'elon musk keep funding key satellite links confirms ukrainian official bestyweb'],
#  [0.38,
#   'kim kardashian tims place start with his family friends next place saturday night night my love you too much more than one most important thing is you'],
#  [0.0, 'elon musk'],
#  [0.0, 'can elon musk remove those promoted tweets comment section'],
#  [0.0,
#   'se o elon musk fosse brasileiro verifica o no twitter 0 taxa de servi o 8'],
#  [0.0, 'mas me disseram que com o elon musk'],
#  [0.0, 'elon musk is set cut around 3 700 jobs at twitter'],
#  [0.0, 'elon musk plans start twitter verification sale as soon as monday'],
#  [0.0,
#   'elon musk 8 d lares las verificaciones elon musk 16 d lares las listas'],
#  [0.0, 'elon musk also owns aoc'],
#  [0.0,
#   'ltima hora elon musk eliminar el 50 de los empleos de twitter bloomberg'],
#  [0.0, ''],
#  [0.0, 'elon musk ousts board named sole director'],
#  [0.0, 'i aswear i dey feel elon musk pass'],
#  [-0.4,
#   'elon musk is expensive you need at least 800 5 mins time is money my dear'],
#  [0.024999999999999994,
#   'i honestly cant wait see elon musk crying over all those fake accounts with checkmarks doing some really offensive tweets whit his name'],
#  [0.0, 'his name is elon musk hahahahahha'],
#  [0.0, 'halts maul elon musk mir doch schei egal ob dir der laden geh rt'],
#  [0.0,
#   'pues elon musk no es tesla ser una cara importante pero seguro hay mujeres que han tomado muchas decisiones en nombre no de musk sino en nombre de tesla as que no hay porque ag itarse'],
#  [0.275,
#   'elon musk is controversial character currently but i made 19 his purchase twitter which will allow me be verified two months buy couple apple pies at mcdonalds'],
#  [0.45,
#   'elon musk when i remind him that food is more important than internet member ship badge'],
#  [-0.15,
#   'everyone praising elon musk remember that he had jeffrey epsteins accomplice ghislaine maxwell at his wedding so image is real image with elon ghislaine cover time magazine was fake'],
#  [0.15833333333333333,
#   'wow elon you are so edgy cool not caring wow i love elon musk so much things he says wow i think i like him more than any other billionaire which i deify which is all them'],
#  [0.04999999999999999,
#   'elon musk is such somehow he just gets more more annoying he s blowhard like trump but without charisma'],
#  [0.0,
#   'i would pay 8 per month twitter but i will never pay elon musk 8 per month twitter'],
#  [0.0, 'this is how elon musk is doing it'],
#  [0.0, 'elon musk could enable twitter s edit button everyone'],
#  [0.0, 'elon musk changed like retweet button these these'],
#  [0.3, 'it s elon musk dog he s being larping as intellectual longest now'],
#  [0.0, 'when you find out elon musk owns child slaves congo'],
#  [0.0, ''],
#  [0.0, 'se o elon musk estragar o twitter juro que crio o twitter dnv'],
#  [0.0,
#   'una pena no pueda expresar adecuadamente el asco que da esta persona y estar feo por motivos evidentes pero le plantaba 27 kys como la copa de un pino y ojal se lo plantease etiquetando al elon musk y la jk pa que lo difundan y poniendo cosas como estas sin iron alguna'],
#  [0.5, 'elon musk s latest twitter poll puts advertisers spot'],
#  [0.25, 'i love it that elon musks inner monolgue is verified account'],
#  [0.0,
#   'would you pay 8 month be verified twitter user heres what people platform verified unverified had say about ceo elon musk s idea'],
#  [-0.5,
#   'well when you begin pay 8 monthly attention space you will begin see value your time give it what is beneficial you i dont see much wrong with elon musks decision adopt scheme'],
#  [-0.6, 'why elon musk is so desperate twitter make money'],
#  [0.0, ''],
#  [0.0, 'le twitter c st moi'],
#  [-0.08333333333333333,
#   'sources elon musk plans cut 3 700 jobs at twitter half companys workforce starting november 4 reverse its existing work anywhere policy bloomberg'],
#  [0.0, 'spoiler alert elon musk'],
#  [0.0, 'bloomberg elon musk eliminate 50 all jobs save costs'],
#  [0.5,
#   'thank you steve saying so eloquently what many millions us think about elon musk megalomaniac i just subscribed warning by steve schmidt'],
#  [0.0, 'twitter laid me off today'],
#  [0.0, 'elon musk don t give f'],
#  [0.0, 'elons plans make twitter money ranked'],
#  [0.0, 'la religion comunista se basa en el ego estas advertido elon musk'],
#  [0.25, 'so tell me exactly what elon musk has contributed society'],
#  [-0.16666666666666666,
#   'elon musk plans cut half twitter employees jobs bloomberg news reporter tweet'],
#  [0.0,
#   'today update breaking elon musk eliminate 50 all twitter jobs save costs per bloomberg'],
#  [-0.8, 'elon musk kinda annoying'],
#  [0.0, ''],
#  [0.0,
#   'e o pior que s o absurdas acabei de ouvir que o elon musk fez um sat lite pra hackear s urnas'],
#  [0.0,
#   'elon musk type cream his jeans when someone says you sir just won internet'],
#  [0.0, 'elon musk could enable twitter s edit button everyone'],
#  [0.2857142857142857,
#   'right wingers are already turning elon musk rolling stone'],
#  [0.0, 'agora v o chamar o elon musk de comunista'],
#  [0.16666666666666666,
#   'elon musk plans charge 8 per month twitter verification status move that has left many users seeing red'],
#  [0.0, 'now i can comment that trump won election thank you elon musk'],
#  [-0.06,
#   'its such science fiction name isnt it you can imagine early episode stargate sg1 where jack oneill antagonises some city elder called elon musk far off planet because daniel jacksons done something big hearted but unfortunate'],
#  [-0.3, 'are u as well rhesus negative just like elon musk'],
#  [-0.09629629629629631,
#   'elon musk plans cut about 3 700 jobs at twitter or half social media company s workforce bid drive down cost twtr']]

# %%
# Create a dataframe of each tweet against its polarity

sentiment_df = pd.DataFrame(sentiment_values, columns=["polarity", "tweet"])

sentiment_df
# Out:
#     polarity                                              tweet
# 0   0.200000  your feedback is appreciated now pay 8 elon mu...
# 1   0.200000  your feedback is appreciated now pay 8 elon mu...
# 2  -0.500000  people who stan billionaires are weird like wh...
# 3  -0.166667                         elon musk cut half twitter
# 4   0.433333                  i can easily beat elon musk fight
# ..       ...                                                ...
# 94  0.166667  elon musk plans charge 8 per month twitter ver...
# 95  0.000000  now i can comment that trump won election than...
# 96 -0.060000  its such science fiction name isnt it you can ...
# 97 -0.300000  are u as well rhesus negative just like elon musk
# 98 -0.096296  elon musk plans cut about 3 700 jobs at twitte...
#
# [99 rows x 2 columns]

# %%
# Save the polarity column as 'n'.

n=sentiment_df["polarity"]

# Convert this column into a series, 'm'. 

m=pd.Series(n)

m
# Out:
# 0     0.200000
# 1     0.200000
# 2    -0.500000
# 3    -0.166667
# 4     0.433333
#         ...
# 94    0.166667
# 95    0.000000
# 96   -0.060000
# 97   -0.300000
# 98   -0.096296
# Name: polarity, Length: 99, dtype: float64

# %%
# Initialize variables, 'pos', 'neg', 'neu'.

pos=0
neg=0
neu=0

# Create a loop to classify the tweets as Positive, Negative, or Neutral.
# Count the number of each.

for items in m:
    if items>0:
        print("Positive")
        pos=pos+1
    elif items<0:
        print("Negative")
        neg=neg+1
    else:
        print("Neutral")
        neu=neu+1
        
print(pos,neg,neu)
# Out:
# Positive
# Positive
# Negative
# Negative
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Negative
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Negative
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Negative
# Neutral
# Positive
# Positive
# Negative
# Neutral
# Negative
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Positive
# Neutral
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Negative
# Positive
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Negative
# Positive
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Negative
# Negative
# Neutral
# Neutral
# Negative
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Negative
# Neutral
# Negative
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Positive
# Neutral
# Negative
# Negative
# Negative
# 23 17 59

# %%
pieLabels=["Positive","Negative","Neutral"]

populationShare=[pos,neg,neu]

figureObject, axesObject = plt.subplots()

axesObject.pie(populationShare,labels=pieLabels,autopct='%1.2f',startangle=90)

axesObject.axis('equal')

plt.show()

# %%
# Display the number of twitter users who feel a certain way about the given topic.

print("%f percent of twitter users feel positive about %s"%(pos,query))

print("%f percent of twitter users feel negative about %s"%(neg,query))

print("%f percent of twitter users feel neutral about %s"%(neu,query))
# Out:
# 23.000000 percent of twitter users feel positive about Elon Musk -is:retweet
# 17.000000 percent of twitter users feel negative about Elon Musk -is:retweet
# 59.000000 percent of twitter users feel neutral about Elon Musk -is:retweet

# %%
# Create a Wordcloud from the tweets

all_words = ' '.join([text for text in cleaned])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # Sentiment Analysis (through Scraping) - Data Mining

# %%
# !pip install snscrape
from datetime import date
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
from textblob import TextBlob
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.3.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.3.4

# %%
tweets_list = []
maxTweets = 1000
# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Covid since:2022-01-01 until:{today}').get_items()):
    if i>maxTweets:
        break
    tweets_list.append([tweet.content])
    
# Creating a dataframe from the tweets list above
tweets_to_df = pd.DataFrame(tweets_list, columns=['Tweets'])
tweets_to_df.shape
# Out:
# (1001, 1)

# %%
tweets_to_df.head() #lists first five tweets
# Out:
#                                               Tweets
# 0  #votenewbluein22.   https://t.co/XbPUT6CmKS.  ...
# 1  On Mar. 2, 2020, I spoke in-person to 100+ sta...
# 2  @MikeDonio Np.  I had to open your profile to ...
# 3  @RedLightning420 Well, I only do vaccine once,...
# 4  Haven’t got covid, like, at all was my persona...

# %%
#clean the tweets with a function
def cleanTweets(text):
    text = re.sub('@[A-Za-z0-9_]+', '', text) #removes @mentions
    text = re.sub('#','',text) #removes hastag '#' symbol
    text = re.sub('RT[\s]+','',text)
    text = re.sub('https?:\/\/\S+', '', text) 
    text = re.sub('\n',' ',text)
    return text
tweets_to_df['cleanedTweets'] = tweets_to_df['Tweets'].apply(cleanTweets) #apply cleanTweet function to the tweet
tweets_to_df.head() #compares original tweets with cleaned Tweets
# Out:
#                                               Tweets  \
# 0  #votenewbluein22.   https://t.co/XbPUT6CmKS.  ...
# 1  On Mar. 2, 2020, I spoke in-person to 100+ sta...
# 2  @MikeDonio Np.  I had to open your profile to ...
# 3  @RedLightning420 Well, I only do vaccine once,...
# 4  Haven’t got covid, like, at all was my persona...
#
#                                        cleanedTweets
# 0  votenewbluein22.        As I told everyone I h...
# 1  On Mar. 2, 2020, I spoke in-person to 100+ sta...
# 2   Np.  I had to open your profile to remember w...
# 3   Well, I only do vaccine once, but I never got...
# 4  Haven’t got covid, like, at all was my persona...

# %%
tweets_to_df.to_csv('tweets_covid.csv') #write dataframe into csv file
savedTweets = pd.read_csv('tweets_covid.csv',index_col=0) #reads csv file

# %%
#get subjectivity and polarity of tweets with a function
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity
#get polarity with a function
def getPolarity(text):
    return TextBlob(text).sentiment.polarity
savedTweets['Subjectivity'] = savedTweets['cleanedTweets'].apply(getSubjectivity)
savedTweets['Polarity'] = savedTweets['cleanedTweets'].apply(getPolarity)
savedTweets.drop('Tweets', axis=1).head() #shows polarity and subjectivity of each tweet and drops the uncleaned tweets column
# Out:
#                                        cleanedTweets  Subjectivity  Polarity
# 0  votenewbluein22.        As I told everyone I h...      0.233333  0.233333
# 1  On Mar. 2, 2020, I spoke in-person to 100+ sta...      0.300000  0.350000
# 2   Np.  I had to open your profile to remember w...      0.677778 -0.100000
# 3   Well, I only do vaccine once, but I never got...      0.866667 -0.083333
# 4  Haven’t got covid, like, at all was my persona...      0.000000  0.000000

# %%
#create a function to check negative, neutral and positive analysis
def getAnalysis(score):
    if score<0:
        return 'Negative'
    elif score ==0:
        return 'Neutral'
    else:
        return 'Positive'
    
savedTweets['Analysis'] = savedTweets['Polarity'].apply(getAnalysis)

# %%
savedTweets['Analysis'].value_counts() #shows the counts of tweets' polarity
# Out:
# Positive    526
# Negative    316
# Neutral     159
# Name: Analysis, dtype: int64

# %%
#plot a bar graph to show count of tweet sentiment
fig = plt.figure(figsize=(7,5))
color = ['green','grey','red']
savedTweets['Analysis'].value_counts().plot(kind='bar',color = color)
plt.title('Value count of tweet polarity')
plt.ylabel('Count')
plt.xlabel('Polarity')
plt.grid(False)
plt.show()

# %%
#pie chart to show percentage distribution of polarity
fig = plt.figure(figsize=(7,7))
colors = ('green', 'grey', 'red')
wp={'linewidth':2, 'edgecolor': 'black'}
tags=savedTweets['Analysis'].value_counts()
explode = (0.1,0.1,0.1)
tags.plot(kind='pie', autopct='%1.1f%%', shadow=True, colors=colors, 
         startangle=90, wedgeprops=wp, explode=explode, label='')
plt.title('Distribution of polarity')
# Out:
# Text(0.5, 1.0, 'Distribution of polarity')

# %%
#plot the polarity and subjectivity on a scatter plot
plt.figure(figsize=(9,7))
for i in range(0,savedTweets.shape[0]):
    plt.scatter(savedTweets['Polarity'][i],savedTweets['Subjectivity'][i], color='blue')
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
#create a function for wordcloud
def create_wordcloud(text):    
    allWords = ' '.join([tweets for tweets in text])
    wordCloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(allWords)
    plt.figure(figsize=(20,10))
    plt.imshow(wordCloud)
    plt.axis('off')
    plt.show()
#wordcloud for positive tweets
posTweets = savedTweets.loc[savedTweets['Analysis']=='Positive', 'cleanedTweets']
create_wordcloud(posTweets)
#wordcloud for negative tweets
negTweets = savedTweets.loc[savedTweets['Analysis']=='Negative', 'cleanedTweets']
create_wordcloud(negTweets)

# %%
#break each tweet sentence into words
sentences = []
for word in savedTweets['cleanedTweets']:
    sentences.append(word)
sentences
lines = list()
for line in sentences:
    words = line.split()
    for w in words:
        lines.append(w)
lines[:10] #shows first 10 words in the first tweet
# Out:
# ['votenewbluein22.',
#  'As',
#  'I',
#  'told',
#  'everyone',
#  'I',
#  'have',
#  'had',
#  'another',
#  'bout']

# %%
#stemming all the words to their root word
stemmer = SnowballStemmer(language='english')
stem=[]
for word in lines:
    stem.append(stemmer.stem(word))
stem[:20]
#removes stopwords (very common words in a sentence)
stem2 = []
for word in stem:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)
#creates a new dataframe for the stem and shows the count of the most used words
df = pd.DataFrame(stem2)
df=df[0].value_counts()
df #shows the new dataframe
# Out:
# covid       742
# today       451
# today.      377
# test        239
# today,      151
#            ...
# normalci      1
# year+,        1
# sore,         1
# two,          1
# mad.          1
# Name: 0, Length: 5813, dtype: int64

# %%
#plots the top 20 used words
df = df[:20]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=0.8)
plt.title('Top Words Overall')
plt.xlabel('Count of words', fontsize=12)
plt.ylabel('Word from Tweet', fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ```
# # Random Stuff
# ```
#
# # Random Stuff

# %%
# This code allows you to get a users timeline
# Replace user ID
# id = '2244994945'
# Elon Musk is 44196397
id = '44196397'
# https://www.codeofaninja.com/tools/find-twitter-id/#:~:text=How%20to%20use%3F&text=Put%20your%20username%20(without%20%40%20sign,appear%20in%20the%20green%20box

tweets = client.get_users_tweets(id=id, tweet_fields=['context_annotations','created_at','geo'])

for tweet in tweets.data:
    print(tweet)
# Out:
# 🤔 https://t.co/XuJdfMTTi1
# https://t.co/BYOBGBHOUA
# @AOC Your feedback is appreciated, now pay $8
# Advertisers should support:
# @itsALLrisky 🤣
# https://t.co/kGncG7Hs3M
# @FridaGhitis $8
# Twitter is simply the most interesting place on the Internet. That’s why you’re reading this tweet right now.
# @RealSpikeCohen The system is working 🤣
# Being attacked by both right &amp; left simultaneously is a good sign

# %%
# Counts for a query
# Replace with your own search query
query = 'covid -is:retweet'

counts = client.get_recent_tweets_count(query=query, granularity='day')

for count in counts.data:
    print(count)
# Out:
# {'end': '2022-10-28T00:00:00.000Z', 'start': '2022-10-27T00:40:40.000Z', 'tweet_count': 142618}
# {'end': '2022-10-29T00:00:00.000Z', 'start': '2022-10-28T00:00:00.000Z', 'tweet_count': 162924}
# {'end': '2022-10-30T00:00:00.000Z', 'start': '2022-10-29T00:00:00.000Z', 'tweet_count': 133996}
# {'end': '2022-10-31T00:00:00.000Z', 'start': '2022-10-30T00:00:00.000Z', 'tweet_count': 139225}
# {'end': '2022-11-01T00:00:00.000Z', 'start': '2022-10-31T00:00:00.000Z', 'tweet_count': 177098}
# {'end': '2022-11-02T00:00:00.000Z', 'start': '2022-11-01T00:00:00.000Z', 'tweet_count': 171850}
# {'end': '2022-11-03T00:00:00.000Z', 'start': '2022-11-02T00:00:00.000Z', 'tweet_count': 170047}
# {'end': '2022-11-03T00:40:40.000Z', 'start': '2022-11-03T00:00:00.000Z', 'tweet_count': 4619}

# 1526643050
# 12
# 344538987
# 29873662
# 18208354
# 3167257102
# 2444425802
# 21292523
# 760345658
# 2263452746
# 2907774137
# 2263437272
# 3101588527
# 905158770107568133
# 26572460
# 25422302
# 446719282
# 19725644
# 987978757
# 150732943
# 2361631088
# 427089628
# 1091459141397180416
# 621573
# 851773048973807617
# 20972371
# 22677790
# 137857547
# 5943622
# 3429950987
# 7267562
# 64488804
# 1558996520
# 11150432
# 14171401
# 289476502
# 5402612

# %%
# Who like a tweet based on the tweet ID
# Replace Tweet ID
id = '1441054496931541004'

users = client.get_liking_users(id=id, user_fields=['profile_image_url'])

for user in users.data:
    print(user)
# Out:
# tejupattigulla
# dontjunod
# Mohamedelh1996
# planerpila
# JacobCardel
# prakoso_ravi
# andlibsh
# philipwanyori
# 4KT_FAMEYE
# ninju9495
# HonKnust
# SangPha53077913
# 2006Babula
# TeamKomanga
# MugishaCohens
# Alvaro93908802
# mokosofojnr
# amelialauraalvi
# RajaSudarshanN1
# SalimOpines
# sandralyn44
# JavanMadvd
# jkwaatei
# fFb2ZjDuBxI7ZYe
# ari0n82
# realsiddarth
# bramelchizedek
# HargovindMistry
# Fitas80056327
# sudheer_nalli
# ravidash2
# Riyapar85333458
# dhivakar_kali
# Michael39048992
# 010Shivam
# Luzinet95688548
# CheleMayera
# prabhakar_pathy
# jackspa84167797
# GBlairsville
# BhashuBhaskar66
# thepranaw
# prescopella
# kayBoat4
# tahsina_
# AtikaIgnatius
# shenmei_
# HillaryMutai_
# girgingizem_
# nahidofficialbd
# Colemanvollrath
# abogadosliti
# kimsonminhoang
# Abdullah_100k
# BestNattpat
# StarrSm16219747
# RyleeArmond
# KirstenAlana
# ian_stevan
# JMarlonPhD
# McmoneyMoni
# dk80ravi
# Shahwezkhan7860
# ginabap
# Nurulai00878936
# fpistorio
# TakasakiCamelot
# cj_apes
# JamesNi04940515
# ositablue1
# boyler
# kennedy798
# whimchic
# turkdevops
# OKaMustMan
# DosiosT
# freudian__slip
# superliane
# SdGurjarNewai
# thesumitgogia
# Aushiker
# dihelander
# TheRealMatt

# %%
#Who retweet a tweet based on tweet id
# Replace Tweet ID
id = '1441054496931541004'

users = client.get_retweeters(id=id, user_fields=['profile_image_url'])

for user in users.data:
    print(user)
# Out:
# RitikaG69283079
# Eli_Krumova
# TwitterREW
# JacobCardel
# ppls_feelings
# CHAITAN42573596
# bhudevsharmaa
# nobody080808080
# shrinivas_pande
# harivarman_M
# ari0n82
# Prince__54
# jackspa84167797
# abogadosliti
# queencharlene95
# tonyv00
# JMarlonPhD
# McmoneyMoni
# dk80ravi
# 15baadr
# viskobatz
# sturner
# liviaiusan
# Aushiker
# pastacoder
# TheRealMatt
# sdatemailfr
# 2006legend
# Dman228
# josephlrice
# lenergeek
# MplusG5
# staherym
# DauphineEnergie
# XY194
# zubabakos
# bakosjen
# CsscUniBo1
# haimvat
# srabi663
# andypiper
# Elvossss
# nahidofficialbd

# %%
# Give me all of the tweets that a user liked
# Replace User ID
id = '44196397'

tweets = client.get_liked_tweets(id=id, tweet_fields=['context_annotations','created_at','geo'])

# “I think that a future where we are a spacefaring civilization and out there among the stars, this is very exciting. This makes me look forward to the future.” @elonmusk
# @elonmusk @WholeMarsBlog "Silly, fun things are important" 😂
#
# https://t.co/rTL7FnQY5K
# Elon Musk Twitter takeover prompts prank that fools mainstream media
#
# https://t.co/VdwQOZdfdM by @ResidentSponge
# @dee_bosa There’s no confusion.
#
# I worked as a Data Engineering Manager up until 7 months ago and Rahul was one of my finest employees. I can’t imagine how one could justify laying him off
# Friends inside Twitter tell me that Ruhal Ligma’s boss, Dinesh Sukondeez has also been laid off and is walking out of the building now. #TwitterTakeover
# If @elonmusk had owned Twitter in October 2020, the @nypost wouldn't have had their huge Hunter Biden scoop so shamefully censored, and the course of the election may have run differently.
# That's why free speech matters &amp; why Musk's determination to restore it is so vital.
# It has recently been 2 years since I started writing. Since then I have only taken 5 days off, 3 of which were due to the war. It is a great pleasure for me to write about Elon &amp; his companies. I sincerely worry about their success, bc the success of mankind depends on it! ❤️ https://t.co/691RQhzvRr
# Let’s unleash the bird.
# Twitter team should be about great engineering not activism.
# 🤣🤣🤣👍 https://t.co/sW0Skbi7ui
# @elonmusk @MikhailaFuller @jordanbpeterson https://t.co/Iz0FcSIb48
# Tesla Giga Berlin Plans Expansion, State Officials Pleased
#
# https://t.co/XlwukDZA06
# SpaceX has launched 111—that's eleventyone in the Shire—Falcon 9 rockets since the last time the company flew a Falcon Heavy.
# Polaris Program donates SpaceX Starlink Internet to over 100 schools in Brazil &amp; Chile
#
# https://t.co/cPT2aKBxfV
# SpaceX launch as seen in Venice Beach at sunset  yesterday https://t.co/DC5Q64ryIo
# Hurray 🍻 !! Bird is freed. Thank you Elon Musk !! https://t.co/LxnnFxpn7w
# @HC_Richardson I don’t think you have anything to worry about.
# Whenever Neville Chamberlain is mentioned in relation to the Ukraine War, it’s a tell that the person doesn’t know what they’re talking about. The correct historical analogy is WWI, not WWII.
#
# https://t.co/2lPAO7J0cV
# Tesla Model Y became Europe's best-selling car in September, leaving the gasoline burning dinosaurs in the dust. Almost 29,400 vehicles were registered in the month, almost 10K!!! units more than its closest competitor, Peugeot 208 😎
# https://t.co/YBBKBalxmz
# Elon Musk's message to Twitter's advertisers not just focuses on the need for ad relevancy, but his love for humanity.
#
# https://t.co/d81SdxBBXP by @JohnnaCrider1
# Tesla Model Y is the best-selling vehicle OF ALL FUEL TYPES in ALL OF EUROPE in September.
#
# 👏 @elonmusk @Tesla https://t.co/gw85v4wkJa
# Tribalism, especially dogmatic tribalism, is silly.
#
# Above all else, we're human. We're one tribe.
# Had a great discussion with @elonmusk last evening! Our continued commitment to brand safety for advertisers remains unchanged.  Looking forward to the future! https://t.co/B7NFJhD2hq
# https://t.co/JKoTQImSqV https://t.co/SzMQ0rd5vz

# %%
# Look up users by twitter ID
# Replace User IDs
ids = ['44196397']

users = client.get_users(ids=ids, user_fields=['profile_image_url'])

for user in users.data:
    print(user.profile_image_url)
for user in users.data:
    print(user)
# Out:
# https://pbs.twimg.com/profile_images/1587290337587904512/Y4s_eu5O_normal.jpg
# elonmusk
